# %%
#Adrian Batista
#loading BeatifulSoap packages
import requests
from bs4 import BeautifulSoup

# %%
# This rotten tomatoes movie list is where data extracting is from
base_site = "https://editorial.rottentomatoes.com/guide/2021-best-movies/"

# %%
response = requests.get(base_site)
response.status_code
# Out:
# 200

# %%
# Getting html from website
html = response.content

# %%
# Converting the HTML into a BeatifulSoup object
soup = BeautifulSoup(html, 'lxml')

# %%
# Making HTML into a file
with open('Rotten_tomatoes_page_2_LXML_Parser.html', 'wb') as file:
    file.write(soup.prettify('utf-8'))

# %%
# filtering div tags containing the following parameters
divs = soup.find_all("div", {"class": "col-sm-18 col-full-xs countdown-item-content"})
divs
# Out:
# [<div class="col-sm-18 col-full-xs countdown-item-content">
#  <div class="row countdown-item-title-bar">
#  <div class="col-sm-20 col-full-xs" style="height: 100%;">
#  <div class="article_movie_title" style="float: left;">
#  <div><h2><a href="https://www.rottentomatoes.com/m/my_salinger_year">My Salinger Year</a> <span class="subtle start-year">(2020)</span> <span class="icon tiny certified" title="Certified Fresh"></span> <span class="tMeterScore">71%</span></h2></div>
#  </div>
#  </div>
#  <div class="col-sm-4 col-full-xs" style="height: 100%;">
#  <div class="countdown-index">#188</div>
#  </div>
#  </div>
#  <div class="row countdown-item-details">
#  <div class="col-sm-24">
# ...

# %%
# Testing to find the title,year, and score of one h2 tag
divs[0].find("h2")
# Out:
# <h2><a href="https://www.rottentomatoes.com/m/my_salinger_year">My Salinger Year</a> <span class="subtle start-year">(2020)</span> <span class="icon tiny certified" title="Certified Fresh"></span> <span class="tMeterScore">71%</span></h2>

# %%
#Finding all the titles, years, and scores from h2 tags
headings = [div.find("h2") for div in divs]
headings
# Out:
# [<h2><a href="https://www.rottentomatoes.com/m/my_salinger_year">My Salinger Year</a> <span class="subtle start-year">(2020)</span> <span class="icon tiny certified" title="Certified Fresh"></span> <span class="tMeterScore">71%</span></h2>,
#  <h2><a href="https://www.rottentomatoes.com/m/palmer">Palmer</a> <span class="subtle start-year">(2021)</span> <span class="icon tiny certified" title="Certified Fresh"></span> <span class="tMeterScore">72%</span></h2>,
#  <h2><a href="https://www.rottentomatoes.com/m/cruella">Cruella</a> <span class="subtle start-year">(2021)</span> <span class="icon tiny certified" title="Certified Fresh"></span> <span class="tMeterScore">74%</span></h2>,
#  <h2><a href="https://www.rottentomatoes.com/m/percy_vs_goliath">Percy Vs Goliath</a> <span class="subtle start-year">(2020)</span> <span class="icon tiny certified" title="Certified Fresh"></span> <span class="tMeterScore">75%</span></h2>,
# ...

# %%
# Inspecting the text inside the headings
[heading.text for heading in headings]
# Out:
# ['My Salinger Year (2020)  71%',
#  'Palmer (2021)  72%',
#  'Cruella (2021)  74%',
#  'Percy Vs Goliath (2020)  75%',
#  'Pixie (2020)  75%',
#  'Blue Bayou (2021)  76%',
#  'The World to Come (2020)  75%',
#  'The Mauritanian (2021)  75%',
#  'Godzilla vs. Kong (2021)  75%',
#  'Spoor (2017)  76%',
#  'Son (2021)  76%',
#  'The Map of Tiny Perfect Things (2021)  76%',
#  'Malignant (2021)  75%',
#  'Surge (2020)  77%',
#  'WeWork: Or the Making and Breaking of a $47 Billion Unicorn (2021)  77%',
#  'Stowaway (2021)  77%',
#  'Shadow in the Cloud (2020)  77%',
#  'Small Engine Repair (2021)  78%',
#  'Bad Trip (2021)  78%',
#  'The Water Man (2020)  78%',
#  'I Care a Lot (2020)  78%',
#  'The Night (2020)  79%',
#  'To All the Boys: Always and Forever (2021)  79%',
#  "Everybody's Talking About Jamie (2021)  79%",
#  'In The Earth (2021)  79%',
#  'Black Widow (2021)  79%',
#  'Safety (2020)  80%',
#  'Cliff Walkers (2021)  80%',
#  'Bloodthirsty (2020)  80%',
# ...

# %%
# Looking at all heading links
[heading.find('a') for heading in headings]
# Out:
# [<a href="https://www.rottentomatoes.com/m/my_salinger_year">My Salinger Year</a>,
#  <a href="https://www.rottentomatoes.com/m/palmer">Palmer</a>,
#  <a href="https://www.rottentomatoes.com/m/cruella">Cruella</a>,
#  <a href="https://www.rottentomatoes.com/m/percy_vs_goliath">Percy Vs Goliath</a>,
#  <a href="https://www.rottentomatoes.com/m/pixie">Pixie</a>,
#  <a href="https://www.rottentomatoes.com/m/blue_bayou_2021">Blue Bayou</a>,
#  <a href="https://www.rottentomatoes.com/m/the_world_to_come">The World to Come</a>,
#  <a href="https://www.rottentomatoes.com/m/the_mauritanian">The Mauritanian</a>,
#  <a href="https://www.rottentomatoes.com/m/godzilla_vs_kong">Godzilla vs. Kong</a>,
#  <a href="https://www.rottentomatoes.com/m/spoor">Spoor</a>,
#  <a href="https://www.rottentomatoes.com/m/son_2021">Son</a>,
#  <a href="https://www.rottentomatoes.com/m/the_map_of_tiny_perfect_things">The Map of Tiny Perfect Things</a>,
# ...

# %%
# Extracting movie titles from the links
movie_names = [heading.find('a').string for heading in headings]
movie_names
# Out:
# ['My Salinger Year',
#  'Palmer',
#  'Cruella',
#  'Percy Vs Goliath',
#  'Pixie',
#  'Blue Bayou',
#  'The World to Come',
#  'The Mauritanian',
#  'Godzilla vs. Kong',
#  'Spoor',
#  'Son',
#  'The Map of Tiny Perfect Things',
#  'Malignant',
#  'Surge',
#  'WeWork: Or the Making and Breaking of a $47 Billion Unicorn',
#  'Stowaway',
#  'Shadow in the Cloud',
#  'Small Engine Repair',
#  'Bad Trip',
#  'The Water Man',
#  'I Care a Lot',
#  'The Night',
#  'To All the Boys: Always and Forever',
#  "Everybody's Talking About Jamie",
#  'In The Earth',
#  'Black Widow',
#  'Safety',
#  'Cliff Walkers',
#  'Bloodthirsty',
#  'Fried Barry',
#  'Knocking',
#  'The Columnist',
#  'Summer of 85',
#  'Concrete Cowboy',
#  'Barb & Star Go to Vista Del Mar',
#  'Free Guy',
#  'The Most Beautiful Boy in the World',
#  'Copshop',
#  'Dementer',
#  'Das Vorspiel',
#  'Misha and the Wolves',
#  'Caveat',
#  'Boys from County Hell',
#  'Gaia',
#  'Fear Street Part One: 1994',
#  'Nobody',
# ...

# %%
# Filtering only spans that containin the year
[heading.find("span", class_ = 'start-year') for heading in headings]
# Out:
# [<span class="subtle start-year">(2020)</span>,
#  <span class="subtle start-year">(2021)</span>,
#  <span class="subtle start-year">(2021)</span>,
#  <span class="subtle start-year">(2020)</span>,
#  <span class="subtle start-year">(2020)</span>,
#  <span class="subtle start-year">(2021)</span>,
#  <span class="subtle start-year">(2020)</span>,
#  <span class="subtle start-year">(2021)</span>,
#  <span class="subtle start-year">(2021)</span>,
#  <span class="subtle start-year">(2017)</span>,
#  <span class="subtle start-year">(2021)</span>,
#  <span class="subtle start-year">(2021)</span>,
#  <span class="subtle start-year">(2021)</span>,
#  <span class="subtle start-year">(2020)</span>,
#  <span class="subtle start-year">(2021)</span>,
#  <span class="subtle start-year">(2021)</span>,
#  <span class="subtle start-year">(2020)</span>,
#  <span class="subtle start-year">(2021)</span>,
#  <span class="subtle start-year">(2021)</span>,
#  <span class="subtle start-year">(2020)</span>,
# ...

# %%
# Extracting the year string from span
years = [heading.find("span", class_ = 'start-year').string for heading in headings]
years
# Out:
# ['(2020)',
#  '(2021)',
#  '(2021)',
#  '(2020)',
#  '(2020)',
#  '(2021)',
#  '(2020)',
#  '(2021)',
#  '(2021)',
#  '(2017)',
#  '(2021)',
#  '(2021)',
#  '(2021)',
#  '(2020)',
#  '(2021)',
#  '(2021)',
#  '(2020)',
#  '(2021)',
#  '(2021)',
#  '(2020)',
#  '(2020)',
#  '(2020)',
#  '(2021)',
#  '(2021)',
#  '(2021)',
#  '(2021)',
#  '(2020)',
#  '(2021)',
#  '(2020)',
#  '(2020)',
#  '(2021)',
#  '(2020)',
#  '(2020)',
#  '(2020)',
#  '(2021)',
#  '(2021)',
#  '(2021)',
#  '(2021)',
#  '(2019)',
#  '(2020)',
#  '(2021)',
#  '(2020)',
#  '(2020)',
#  '(2021)',
#  '(2021)',
#  '(2021)',
#  '(2020)',
#  '(2019)',
#  '(2021)',
#  '(2021)',
#  '(2021)',
#  '(2021)',
#  '(2021)',
#  '(2021)',
#  '(2021)',
#  '(2020)',
#  '(2021)',
#  '(2021)',
#  '(2021)',
#  '(2021)',
#  '(2021)',
#  '(2020)',
#  '(2020)',
#  '(2020)',
#  '(2020)',
#  '(2021)',
#  '(2018)',
#  '(2021)',
#  '(2021)',
#  '(2021)',
#  '(2021)',
#  '(2021)',
#  '(2020)',
#  '(2020)',
#  '(2021)',
#  '(2020)',
# ...

# %%
years[0]
# Out:
# '(2020)'

# %%
years[0].strip('()')
# Out:
# '2020'

# %%
# Updating years with stripped values
years = [year.strip('()') for year in years]
years
# Out:
# ['2020',
#  '2021',
#  '2021',
#  '2020',
#  '2020',
#  '2021',
#  '2020',
#  '2021',
#  '2021',
#  '2017',
#  '2021',
#  '2021',
#  '2021',
#  '2020',
#  '2021',
#  '2021',
#  '2020',
#  '2021',
#  '2021',
#  '2020',
#  '2020',
#  '2020',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2020',
#  '2021',
#  '2020',
#  '2020',
#  '2021',
#  '2020',
#  '2020',
#  '2020',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2019',
#  '2020',
#  '2021',
#  '2020',
#  '2020',
#  '2021',
#  '2021',
#  '2021',
#  '2020',
#  '2019',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2020',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2020',
#  '2020',
#  '2020',
#  '2020',
#  '2021',
#  '2018',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2020',
#  '2020',
#  '2021',
#  '2020',
#  '2021',
#  '2019',
#  '2021',
#  '2021',
#  '2020',
#  '2021',
#  '2020',
#  '2020',
#  '2020',
#  '2020',
#  '2020',
#  '2020',
#  '2020',
#  '2021',
# ...

# %%
# Converting all the year strings to integers
years = [int(year) for year in years]
years
# Out:
# [2020,
#  2021,
#  2021,
#  2020,
#  2020,
#  2021,
#  2020,
#  2021,
#  2021,
#  2017,
#  2021,
#  2021,
#  2021,
#  2020,
#  2021,
#  2021,
#  2020,
#  2021,
#  2021,
#  2020,
#  2020,
#  2020,
#  2021,
#  2021,
#  2021,
#  2021,
#  2020,
#  2021,
#  2020,
#  2020,
#  2021,
#  2020,
#  2020,
#  2020,
#  2021,
#  2021,
#  2021,
#  2021,
#  2019,
#  2020,
#  2021,
#  2020,
#  2020,
#  2021,
#  2021,
#  2021,
#  2020,
#  2019,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2020,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2020,
#  2020,
#  2020,
#  2020,
#  2021,
#  2018,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2020,
#  2020,
#  2021,
#  2020,
#  2021,
#  2019,
#  2021,
#  2021,
#  2020,
#  2021,
#  2020,
#  2020,
#  2020,
#  2020,
#  2020,
#  2020,
#  2020,
#  2021,
#  2019,
#  2019,
#  2021,
#  2021,
#  2020,
#  2020,
#  2020,
#  2020,
#  2020,
#  2021,
#  2021,
#  2021,
#  2020,
#  2019,
#  2021,
#  2020,
#  2020,
#  2020,
#  2020,
#  2021,
#  2019,
# ...

# %%
# Filtering only the spans containing the score
[heading.find("span", class_ = 'tMeterScore') for heading in headings]
# Out:
# [<span class="tMeterScore">71%</span>,
#  <span class="tMeterScore">72%</span>,
#  <span class="tMeterScore">74%</span>,
#  <span class="tMeterScore">75%</span>,
#  <span class="tMeterScore">75%</span>,
#  <span class="tMeterScore">76%</span>,
#  <span class="tMeterScore">75%</span>,
#  <span class="tMeterScore">75%</span>,
#  <span class="tMeterScore">75%</span>,
#  <span class="tMeterScore">76%</span>,
#  <span class="tMeterScore">76%</span>,
#  <span class="tMeterScore">76%</span>,
#  <span class="tMeterScore">75%</span>,
#  <span class="tMeterScore">77%</span>,
#  <span class="tMeterScore">77%</span>,
#  <span class="tMeterScore">77%</span>,
#  <span class="tMeterScore">77%</span>,
#  <span class="tMeterScore">78%</span>,
#  <span class="tMeterScore">78%</span>,
#  <span class="tMeterScore">78%</span>,
#  <span class="tMeterScore">78%</span>,
#  <span class="tMeterScore">79%</span>,
#  <span class="tMeterScore">79%</span>,
#  <span class="tMeterScore">79%</span>,
# ...

# %%
# Extracting the score string
scores = [heading.find("span", class_ = 'tMeterScore').string for heading in headings]
scores
# Out:
# ['71%',
#  '72%',
#  '74%',
#  '75%',
#  '75%',
#  '76%',
#  '75%',
#  '75%',
#  '75%',
#  '76%',
#  '76%',
#  '76%',
#  '75%',
#  '77%',
#  '77%',
#  '77%',
#  '77%',
#  '78%',
#  '78%',
#  '78%',
#  '78%',
#  '79%',
#  '79%',
#  '79%',
#  '79%',
#  '79%',
#  '80%',
#  '80%',
#  '80%',
#  '80%',
#  '80%',
#  '80%',
#  '80%',
#  '80%',
#  '80%',
#  '80%',
#  '81%',
#  '82%',
#  '83%',
#  '83%',
#  '83%',
#  '83%',
#  '83%',
#  '83%',
#  '83%',
#  '83%',
#  '84%',
#  '84%',
#  '84%',
#  '83%',
#  '84%',
#  '86%',
#  '86%',
#  '86%',
#  '87%',
#  '86%',
#  '86%',
#  '88%',
#  '86%',
#  '86%',
#  '86%',
#  '85%',
#  '86%',
#  '86%',
#  '88%',
#  '87%',
#  '88%',
#  '88%',
#  '88%',
#  '88%',
#  '88%',
#  '88%',
#  '88%',
#  '88%',
#  '88%',
#  '88%',
#  '88%',
#  '89%',
#  '89%',
#  '89%',
#  '89%',
#  '89%',
#  '90%',
#  '90%',
#  '90%',
#  '90%',
#  '90%',
#  '90%',
#  '90%',
#  '90%',
#  '90%',
#  '90%',
#  '90%',
#  '90%',
#  '90%',
#  '91%',
#  '91%',
#  '91%',
#  '91%',
#  '91%',
# ...

# %%
# Removing the '%' sign
scores = [s.strip('%') for s in scores]
scores
# Out:
# ['71',
#  '72',
#  '74',
#  '75',
#  '75',
#  '76',
#  '75',
#  '75',
#  '75',
#  '76',
#  '76',
#  '76',
#  '75',
#  '77',
#  '77',
#  '77',
#  '77',
#  '78',
#  '78',
#  '78',
#  '78',
#  '79',
#  '79',
#  '79',
#  '79',
#  '79',
#  '80',
#  '80',
#  '80',
#  '80',
#  '80',
#  '80',
#  '80',
#  '80',
#  '80',
#  '80',
#  '81',
#  '82',
#  '83',
#  '83',
#  '83',
#  '83',
#  '83',
#  '83',
#  '83',
#  '83',
#  '84',
#  '84',
#  '84',
#  '83',
#  '84',
#  '86',
#  '86',
#  '86',
#  '87',
#  '86',
#  '86',
#  '88',
#  '86',
#  '86',
#  '86',
#  '85',
#  '86',
#  '86',
#  '88',
#  '87',
#  '88',
#  '88',
#  '88',
#  '88',
#  '88',
#  '88',
#  '88',
#  '88',
#  '88',
#  '88',
#  '88',
#  '89',
#  '89',
#  '89',
#  '89',
#  '89',
#  '90',
#  '90',
#  '90',
#  '90',
#  '90',
#  '90',
#  '90',
#  '90',
#  '90',
#  '90',
#  '90',
#  '90',
#  '90',
#  '91',
#  '91',
#  '91',
#  '91',
#  '91',
#  '91',
#  '91',
#  '92',
#  '92',
#  '92',
#  '92',
#  '92',
#  '92',
#  '92',
#  '92',
#  '92',
# ...

# %%
# Converting each score to an integer
scores = [int(s) for s in scores]
scores
# Out:
# [71,
#  72,
#  74,
#  75,
#  75,
#  76,
#  75,
#  75,
#  75,
#  76,
#  76,
#  76,
#  75,
#  77,
#  77,
#  77,
#  77,
#  78,
#  78,
#  78,
#  78,
#  79,
#  79,
#  79,
#  79,
#  79,
#  80,
#  80,
#  80,
#  80,
#  80,
#  80,
#  80,
#  80,
#  80,
#  80,
#  81,
#  82,
#  83,
#  83,
#  83,
#  83,
#  83,
#  83,
#  83,
#  83,
#  84,
#  84,
#  84,
#  83,
#  84,
#  86,
#  86,
#  86,
#  87,
#  86,
#  86,
#  88,
#  86,
#  86,
#  86,
#  85,
#  86,
#  86,
#  88,
#  87,
#  88,
#  88,
#  88,
#  88,
#  88,
#  88,
#  88,
#  88,
#  88,
#  88,
#  88,
#  89,
#  89,
#  89,
#  89,
#  89,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  91,
#  91,
#  91,
#  91,
#  91,
#  91,
#  91,
#  92,
#  92,
#  92,
#  92,
#  92,
#  92,
#  92,
#  92,
#  92,
#  92,
#  93,
#  93,
#  93,
#  93,
#  93,
#  93,
#  93,
#  93,
#  93,
#  93,
#  93,
#  93,
#  93,
#  93,
#  94,
#  94,
#  94,
#  94,
#  95,
#  95,
#  95,
#  95,
#  95,
#  95,
#  95,
#  95,
#  95,
#  96,
#  96,
#  96,
# ...

# %%
# Now i am looking for the critics consensus
divs
# Out:
# [<div class="col-sm-18 col-full-xs countdown-item-content">
#  <div class="row countdown-item-title-bar">
#  <div class="col-sm-20 col-full-xs" style="height: 100%;">
#  <div class="article_movie_title" style="float: left;">
#  <div><h2><a href="https://www.rottentomatoes.com/m/my_salinger_year">My Salinger Year</a> <span class="subtle start-year">(2020)</span> <span class="icon tiny certified" title="Certified Fresh"></span> <span class="tMeterScore">71%</span></h2></div>
#  </div>
#  </div>
#  <div class="col-sm-4 col-full-xs" style="height: 100%;">
#  <div class="countdown-index">#188</div>
#  </div>
#  </div>
#  <div class="row countdown-item-details">
#  <div class="col-sm-24">
# ...

# %%
# Getting the 'div' tags containing the critics consensus
consensus = [div.find("div", {"class": "info critics-consensus"}) for div in divs]
consensus
# Out:
# [<div class="info critics-consensus"><span class="descriptor">Critics Consensus:</span> No consensus yet.</div>,
#  <div class="info critics-consensus"><span class="descriptor">Critics Consensus:</span> Although it traffics in familiar territory, <em>Palmer</em> is elevated by worthy themes and a strong ensemble led by an impressive Justin Timberlake.</div>,
#  <div class="info critics-consensus"><span class="descriptor">Critics Consensus:</span> <em>Cruella</em> can't quite answer the question of why its title character needed an origin story, but this dazzling visual feast is awfully fun to watch whenever its leading ladies lock horns.</div>,
#  <div class="info critics-consensus"><span class="descriptor">Critics Consensus:</span> <em>Percy vs Goliath</em> teeters toward heavy-handed messaging, but Christopher Walken's work in the central role helps keep this fact-based story upright.</div>,
# ...

# %%
# looking at the text inside these tags
[con.text for con in consensus]
# Out:
# ['Critics Consensus: No consensus yet.',
#  'Critics Consensus: Although it traffics in familiar territory, Palmer is elevated by worthy themes and a strong ensemble led by an impressive Justin Timberlake.',
#  "Critics Consensus: Cruella can't quite answer the question of why its title character needed an origin story, but this dazzling visual feast is awfully fun to watch whenever its leading ladies lock horns.",
#  "Critics Consensus: Percy vs Goliath teeters toward heavy-handed messaging, but Christopher Walken's work in the central role helps keep this fact-based story upright.",
#  "Critics Consensus: Pixie borrows shamelessly from multiple like-minded heist thrillers; fortunately, Olivia Cooke's outstanding lead performance makes for a great getaway vehicle.",
#  'Critics Consensus: Blue Bayou can be indelicate in its attempts to tug the heartstrings, but solid acting and a genuinely affecting story make this drama difficult to ignore.',
# ...

# %%
#Now its going to be remove from the final texts
consensus[0]
# Out:
# <div class="info critics-consensus"><span class="descriptor">Critics Consensus:</span> No consensus yet.</div>

# %%
consensus[0].contents
# Out:
# [<span class="descriptor">Critics Consensus:</span>, ' No consensus yet.']

# %%
# The second element of that list is the text that will be removed
consensus[0].contents[1]
# Out:
# ' No consensus yet.'

# %%
# Remmoving the extra white space with the strip method
consensus[0].contents[1].strip()
# Out:
# 'No consensus yet.'

# %%
# Processing all texts
consensus_text = [con.contents[1].strip() for con in consensus]
consensus_text
# Out:
# ['No consensus yet.',
#  'Although it traffics in familiar territory,',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Delivering squarely on its title,',
#  '',
#  'A horror story with unexpected emotional resonance,',
#  "Its characters' time-loop journey is a little bumpy and fairly familiar, but heartfelt charm and likeable leads make",
#  'Although',
#  'Discomfiting by design,',
#  "It's hard to ignore the parts that are left unexamined, but",
#  'Pacing problems prevent',
#  'Part creature feature, part war movie, and part social commentary,',
#  'No consensus yet.',
#  'With ingeniously gross hidden-camera bits that often find their unsuspecting marks at their best,',
#  'No consensus yet.',
#  'A searing swipe at late-stage capitalism,',
#  'The dramatic heft and dread of',
#  'Diminishing returns have set in for this trilogy, but',
#  'It may not be as effervescent as its title character, but',
#  '',
#  '',
#  'Fans of uplifting sports dramas will find',
# ...

# %%
# Extracting all director divs
directors = [div.find("div", class_ = 'director') for div in divs]
directors
# Out:
# [<div class="info director">
#  <span class="descriptor">Directed By:</span> <a class="" href="//www.rottentomatoes.com/celebrity/1184849-philippe_falardeau">Philippe Falardeau</a></div>,
#  <div class="info director">
#  <span class="descriptor">Directed By:</span> <a class="" href="//www.rottentomatoes.com/celebrity/fisher_stevens">Fisher Stevens</a></div>,
#  <div class="info director">
#  <span class="descriptor">Directed By:</span> <a class="" href="//www.rottentomatoes.com/celebrity/craig-gillespie">Craig Gillespie</a></div>,
#  <div class="info director">
#  <span class="descriptor">Directed By:</span> <a class="" href="//www.rottentomatoes.com/celebrity/clark_johnson">Clark Johnson</a></div>,
#  <div class="info director">
#  <span class="descriptor">Directed By:</span> <a class="" href="//www.rottentomatoes.com/celebrity/1064382-barnaby_thompson">Barnaby Thompson</a></div>,
#  <div class="info director">
# ...

# %%
# Inspecting a div containing director information
directors[0]
# Out:
# <div class="info director">
# <span class="descriptor">Directed By:</span> <a class="" href="//www.rottentomatoes.com/celebrity/1184849-philippe_falardeau">Philippe Falardeau</a></div>

# %%
# Obtaining all director links
[director.find("a") for director in directors]
# Out:
# [<a class="" href="//www.rottentomatoes.com/celebrity/1184849-philippe_falardeau">Philippe Falardeau</a>,
#  <a class="" href="//www.rottentomatoes.com/celebrity/fisher_stevens">Fisher Stevens</a>,
#  <a class="" href="//www.rottentomatoes.com/celebrity/craig-gillespie">Craig Gillespie</a>,
#  <a class="" href="//www.rottentomatoes.com/celebrity/clark_johnson">Clark Johnson</a>,
#  <a class="" href="//www.rottentomatoes.com/celebrity/1064382-barnaby_thompson">Barnaby Thompson</a>,
#  <a class="" href="//www.rottentomatoes.com/celebrity/justin-chon">Justin Chon</a>,
#  <a class="" href="//www.rottentomatoes.com/celebrity/mona_fastvold">Mona Fastvold</a>,
#  <a class="" href="//www.rottentomatoes.com/celebrity/kevin_macdonald">Kevin Macdonald</a>,
#  <a class="" href="//www.rottentomatoes.com/celebrity/adam_wingard">Adam Wingard</a>,
#  <a class="" href="//www.rottentomatoes.com/celebrity/agnieszka_holland">Agnieszka Holland</a>,
# ...

# %%
# I am using if-else to deal with the None values if there are any

final_directors = [None if director.find("a") is None else director.find("a").string for director in directors]
final_directors
# Out:
# ['Philippe Falardeau',
#  'Fisher Stevens',
#  'Craig Gillespie',
#  'Clark Johnson',
#  'Barnaby Thompson',
#  'Justin Chon',
#  'Mona Fastvold',
#  'Kevin Macdonald',
#  'Adam Wingard',
#  'Agnieszka Holland',
#  'Ivan Kavanagh',
#  'Ian Samuels',
#  'James Wan',
#  'Aneil Karia',
#  'Jed Rothstein',
#  'Joe Penna',
#  'Roseanne Liang',
#  'John Pollono',
#  'Kitao Sakurai',
#  'David Oyelowo',
#  'J Blakeson',
#  'Kourosh Ahari',
#  'Michael Fimognari',
#  'Jonathan Butterell',
#  'Ben Wheatley',
#  'Cate Shortland',
#  'Reginald Hudlin',
#  'Zhang Yimou',
#  'Amelia Moses',
#  'Ryan Kruger',
#  'Frida Kempff',
#  'Ivo van Aart',
#  'FranÃ§ois Ozon',
#  'Ricky Staub',
#  'Josh Greenbaum',
#  'Shawn Levy',
#  'Kristina LindstrÃ¶m',
#  'Joe Carnahan',
#  'Chad Crawford Kinkle',
#  'Ina Weisse',
#  'Sam Hobkinson',
#  'Damian Mc Carthy',
#  'Chris Baugh',
#  'Jaco Bouwer',
#  'Leigh Janiak',
#  'Ilya Naishuller',
#  'Charles Officer',
#  'Danielle Lessovitz',
#  'Corinna Faith',
# ...

# %%
cast_info = [div.find("div", class_ = 'cast') for div in divs]
cast_info
# Out:
# [<div class="info cast">
#  <span class="descriptor">Starring:</span> <a class="" href="//www.rottentomatoes.com/celebrity/margaret_qualley">Margaret Qualley</a>, <a class="" href="//www.rottentomatoes.com/celebrity/sigourney_weaver">Sigourney Weaver</a>, <a class="" href="//www.rottentomatoes.com/celebrity/douglas_booth">Douglas Booth</a>, <a class="" href="//www.rottentomatoes.com/celebrity/seana_kerslake">SeÃ¡na Kerslake</a></div>,
#  <div class="info cast">
#  <span class="descriptor">Starring:</span> <a class="" href="//www.rottentomatoes.com/celebrity/justin_timberlake">Justin Timberlake</a>, <a class="" href="//www.rottentomatoes.com/celebrity/juno-temple">Juno Temple</a>, <a class="" href="//www.rottentomatoes.com/celebrity/alisha_wainwright">Alisha Wainwright</a>, <a class="" href="//www.rottentomatoes.com/celebrity/june_squibb_2">June Squibb</a></div>,
#  <div class="info cast">
# ...

# %%
cast_info[0]
# Out:
# <div class="info cast">
# <span class="descriptor">Starring:</span> <a class="" href="//www.rottentomatoes.com/celebrity/margaret_qualley">Margaret Qualley</a>, <a class="" href="//www.rottentomatoes.com/celebrity/sigourney_weaver">Sigourney Weaver</a>, <a class="" href="//www.rottentomatoes.com/celebrity/douglas_booth">Douglas Booth</a>, <a class="" href="//www.rottentomatoes.com/celebrity/seana_kerslake">SeÃ¡na Kerslake</a></div>

# %%
# Obtain all the links to different cast members
cast_links = cast_info[0].find_all('a')
cast_links
# Out:
# [<a class="" href="//www.rottentomatoes.com/celebrity/margaret_qualley">Margaret Qualley</a>,
#  <a class="" href="//www.rottentomatoes.com/celebrity/sigourney_weaver">Sigourney Weaver</a>,
#  <a class="" href="//www.rottentomatoes.com/celebrity/douglas_booth">Douglas Booth</a>,
#  <a class="" href="//www.rottentomatoes.com/celebrity/seana_kerslake">SeÃ¡na Kerslake</a>]

# %%
# Extracting the names of cast members from the links
cast_names = [link.string for link in cast_links]
cast_names
# Out:
# ['Margaret Qualley', 'Sigourney Weaver', 'Douglas Booth', 'SeÃ¡na Kerslake']

# %%
# Stitching the names together makes it easier to read
cast = ", ".join(cast_names)
cast
# Out:
# 'Margaret Qualley, Sigourney Weaver, Douglas Booth, SeÃ¡na Kerslake'

# %%
# Initialize the list of all cast memners
cast = []

for c in cast_info:
    cast_links = c.find_all('a')
    cast_names = [link.string for link in cast_links]
    
    cast.append(", ".join(cast_names)) # Joining is optional

cast
# Out:
# ['Margaret Qualley, Sigourney Weaver, Douglas Booth, SeÃ¡na Kerslake',
#  'Justin Timberlake, Juno Temple, Alisha Wainwright, June Squibb',
#  'Emma Stone, Emma Thompson, Joel Fry, Paul Walter Hauser',
#  'Peter Stebbings',
#  'Dylan Moran, Chris Walley',
#  "Justin Chon, Alicia Vikander, Mark O'Brien, Linh Dan Pham",
#  'Katherine Waterston, Vanessa Kirby, Casey Affleck, Christopher Abbott',
#  'Jodie Foster, Tahar Rahim, Shailene Woodley, Benedict Cumberbatch',
#  'Alexander SkarsgÃ¥rd, Millie Bobby Brown, Rebecca Hall, Brian Tyree Henry',
#  'Agnieszka Mandat-Grabka, Wiktor Zborowski, Jakub GierszaÅ\x82, Patrycja Volny',
#  'Andi Matichak, Emile Hirsch, Luke David Blumm, Rocco Sisto',
#  'Kathryn Newton, Kyle Allen, Jermaine Harris, Anna Mikami',
#  'Annabelle Wallis, Maddie Hasson, George Young, Michole Briana White',
#  'Ben Whishaw, Ellie Haddington, Ian Gelder, Jasmine Jobson',
#  'Adam Neumann',
#  'Anna Kendrick, Daniel Dae Kim, Toni Collette, Shamier Anderson',
# ...

# %%
# This can also be done using Nested list but its way harder to read

cast = [", ".join([link.string for link in c.find_all("a")]) for c in cast_info]
cast
# Out:
# ['Margaret Qualley, Sigourney Weaver, Douglas Booth, SeÃ¡na Kerslake',
#  'Justin Timberlake, Juno Temple, Alisha Wainwright, June Squibb',
#  'Emma Stone, Emma Thompson, Joel Fry, Paul Walter Hauser',
#  'Peter Stebbings',
#  'Dylan Moran, Chris Walley',
#  "Justin Chon, Alicia Vikander, Mark O'Brien, Linh Dan Pham",
#  'Katherine Waterston, Vanessa Kirby, Casey Affleck, Christopher Abbott',
#  'Jodie Foster, Tahar Rahim, Shailene Woodley, Benedict Cumberbatch',
#  'Alexander SkarsgÃ¥rd, Millie Bobby Brown, Rebecca Hall, Brian Tyree Henry',
#  'Agnieszka Mandat-Grabka, Wiktor Zborowski, Jakub GierszaÅ\x82, Patrycja Volny',
#  'Andi Matichak, Emile Hirsch, Luke David Blumm, Rocco Sisto',
#  'Kathryn Newton, Kyle Allen, Jermaine Harris, Anna Mikami',
#  'Annabelle Wallis, Maddie Hasson, George Young, Michole Briana White',
#  'Ben Whishaw, Ellie Haddington, Ian Gelder, Jasmine Jobson',
#  'Adam Neumann',
#  'Anna Kendrick, Daniel Dae Kim, Toni Collette, Shamier Anderson',
# ...

# %%
# The adjusted scores can be found in a div with class 'info countdown-adjusted-score'
adj_scores = [div.find("div", {"class": "info countdown-adjusted-score"}) for div in divs]
adj_scores
# Out:
# [<div class="info countdown-adjusted-score"><span class="descriptor">Adjusted Score: </span>75253% <span class="glyphicon glyphicon-question-sign" data-html="true" data-original-title="The Adjusted Score comes from a weighted formula (Bayesian) that we use that accounts for variation in the number of reviews per movie." data-placement="top" data-toggle="tooltip" rel="tooltip" title=""></span></div>,
#  <div class="info countdown-adjusted-score"><span class="descriptor">Adjusted Score: </span>77750% <span class="glyphicon glyphicon-question-sign" data-html="true" data-original-title="The Adjusted Score comes from a weighted formula (Bayesian) that we use that accounts for variation in the number of reviews per movie." data-placement="top" data-toggle="tooltip" rel="tooltip" title=""></span></div>,
# ...

# %%
adj_scores[0]
# Out:
# <div class="info countdown-adjusted-score"><span class="descriptor">Adjusted Score: </span>75253% <span class="glyphicon glyphicon-question-sign" data-html="true" data-original-title="The Adjusted Score comes from a weighted formula (Bayesian) that we use that accounts for variation in the number of reviews per movie." data-placement="top" data-toggle="tooltip" rel="tooltip" title=""></span></div>

# %%
adj_scores[0].contents[1]
# Out:
# '75253% '

# %%
# Extracting the string (without '%' sign and extra space)
adj_scores_clean = [score.contents[1].strip('% ') for score in adj_scores]
adj_scores_clean
# Out:
# ['75253',
#  '77750',
#  '96584',
#  '77000',
#  '77250',
#  '79879',
#  '81875',
#  '86230',
#  '97726',
#  '76563',
#  '77616',
#  '79500',
#  '83346',
#  '78250',
#  '78491',
#  '82379',
#  '83728',
#  '79065',
#  '80500',
#  '81562',
#  '90562',
#  '81877',
#  '81375',
#  '82629',
#  '87250',
#  '104942',
#  '82001',
#  '81856',
#  '82125',
#  '81699',
#  '83125',
#  '82937',
#  '83858',
#  '86649',
#  '89687',
#  '96520',
#  '83000',
#  '86444',
#  '82433',
#  '83993',
#  '84625',
#  '83884',
#  '84625',
#  '85750',
#  '88672',
#  '99001',
#  '84689',
#  '84679',
#  '85437',
#  '104164',
#  '103736',
#  '98532',
#  '87750',
#  '88198',
#  '90651',
#  '90375',
#  '89707',
#  '93949',
#  '90910',
#  '91233',
#  '92625',
#  '93812',
#  '97261',
#  '98829',
#  '88991',
#  '89312',
#  '89789',
#  '90187',
#  '89574',
#  '92921',
#  '92187',
#  '92627',
#  '94943',
#  '95937',
#  '95856',
#  '100960',
#  '103714',
#  '90221',
#  '90878',
#  '93312',
#  '95275',
#  '96375',
# ...

# %%
# Converting the strings to numbers 
final_adj = [float(score) for score in adj_scores_clean] 
final_adj
# Out:
# [75253.0,
#  77750.0,
#  96584.0,
#  77000.0,
#  77250.0,
#  79879.0,
#  81875.0,
#  86230.0,
#  97726.0,
#  76563.0,
#  77616.0,
#  79500.0,
#  83346.0,
#  78250.0,
#  78491.0,
#  82379.0,
#  83728.0,
#  79065.0,
#  80500.0,
#  81562.0,
#  90562.0,
#  81877.0,
#  81375.0,
#  82629.0,
#  87250.0,
#  104942.0,
#  82001.0,
#  81856.0,
#  82125.0,
#  81699.0,
#  83125.0,
#  82937.0,
#  83858.0,
#  86649.0,
#  89687.0,
#  96520.0,
#  83000.0,
#  86444.0,
#  82433.0,
#  83993.0,
#  84625.0,
#  83884.0,
#  84625.0,
#  85750.0,
#  88672.0,
#  99001.0,
#  84689.0,
#  84679.0,
#  85437.0,
#  104164.0,
#  103736.0,
#  98532.0,
#  87750.0,
#  88198.0,
#  90651.0,
#  90375.0,
#  89707.0,
#  93949.0,
#  90910.0,
#  91233.0,
#  92625.0,
#  93812.0,
#  97261.0,
#  98829.0,
#  88991.0,
#  89312.0,
#  89789.0,
#  90187.0,
#  89574.0,
#  92921.0,
#  92187.0,
#  92627.0,
#  94943.0,
#  95937.0,
#  95856.0,
#  100960.0,
#  103714.0,
#  90221.0,
#  90878.0,
#  93312.0,
#  95275.0,
#  96375.0,
# ...

# %%
# The synopsis is located inside a 'div' tag with the class 'info synopsis'
synopsis = [div.find('div', class_='synopsis') for div in divs]
synopsis
# Out:
# [<div class="info synopsis"><span class="descriptor">Synopsis:</span> New York in the 90s: After leaving graduate school to pursue her dream of becoming a writer, Joanna (Margaret Qualley)...<a class="" data-pageheader="" href="https://www.rottentomatoes.com/m/my_salinger_year" target="_top"> [More]</a></div>,
#  <div class="info synopsis"><span class="descriptor">Synopsis:</span> Former high school football star Eddie Palmer (Justin Timberlake) went from hometown hero to convicted felon, earning himself 12 years...<a class="" data-pageheader="" href="https://www.rottentomatoes.com/m/palmer" target="_top"> [More]</a></div>,
#  <div class="info synopsis"><span class="descriptor">Synopsis:</span> Academy Award (R) winner Emma Stone ("La La Land") stars in Disney's "Cruella," an all-new live-action feature film about the...<a class="" data-pageheader="" href="https://www.rottentomatoes.com/m/cruella" target="_top"> [More]</a></div>,
# ...

# %%
# Inspecting the element
synopsis[0]
# Out:
# <div class="info synopsis"><span class="descriptor">Synopsis:</span> New York in the 90s: After leaving graduate school to pursue her dream of becoming a writer, Joanna (Margaret Qualley)...<a class="" data-pageheader="" href="https://www.rottentomatoes.com/m/my_salinger_year" target="_top"> [More]</a></div>

# %%
# The text is the second child
synopsis[0].contents[1]
# Out:
# ' New York in the 90s: After leaving graduate school to pursue her dream of becoming a writer, Joanna (Margaret Qualley)...'

# %%
# Extracting the text
synopsis_text = [syn.contents[1] for syn in synopsis]
synopsis_text
# Out:
# [' New York in the 90s: After leaving graduate school to pursue her dream of becoming a writer, Joanna (Margaret Qualley)...',
#  ' Former high school football star Eddie Palmer (Justin Timberlake) went from hometown hero to convicted felon, earning himself 12 years...',
#  ' Academy Award (R) winner Emma Stone ("La La Land") stars in Disney\'s "Cruella," an all-new live-action feature film about the...',
#  ' Academy AwardÂ® Winner Christopher Walken*, Zach Braff and Christina Ricci star in the true story of a small-town farmer taking...',
#  " Pixie Hardy sets out to avenge her mother's death and attempts a heist that will give her the means to...",
#  ' From award-winning writer/director Justin Chon, Blue Bayou is the moving and timely story of a uniquely American family fighting for...',
#  " In this powerful 19th century romance set in the American Northeast, Abigail (Katherine Waterston), a farmer's wife, and her new...",
# ...

# %% [markdown]
# # Representing the data in structured form

# %%
# use pandas and its dataframe for data storage

# %%
# load the pandas package
import pandas as pd

# %% [markdown]
# ## Creating a Data Frame

# %%
movies_info = pd.DataFrame()
movies_info
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# Populating the dataframe

movies_info["Movie Title"] = movie_names
movies_info["Year"] = years
movies_info["Score"] = scores
movies_info["Adjusted Score"] = final_adj 
movies_info["Director"] = final_directors
movies_info["Synopsis"] = synopsis_text    
movies_info["Cast"] = cast
movies_info["Consensus"] = consensus_text


movies_info
# Out:
#               Movie Title  Year  Score  Adjusted Score            Director  \
# 0    My Salinger Year      2020  71     75253.0         Philippe Falardeau
# 1    Palmer                2021  72     77750.0         Fisher Stevens
# 2    Cruella               2021  74     96584.0         Craig Gillespie
# 3    Percy Vs Goliath      2020  75     77000.0         Clark Johnson
# 4    Pixie                 2020  75     77250.0         Barnaby Thompson
# ..     ...                  ...  ..         ...                      ...
# 183  Mayor                 2020  100    101625.0        David Osit
# 184  Slalom                2020  100    102197.0        CharlÃ¨ne Favier
# 185  Identifying Features  2020  98     100788.0        Fernanda Valadez
# 186  Quo Vadis, Aida?      2020  100    102875.0        Jasmila Zbanic
# 187  76 Days               2020  100    105125.0        Hao Wu
#
# ...

# %%
# Needs to be changed so the whole column can fit text 
pd.set_option('display.max_colwidth', -1)
movies_info
# Out:
# <ipython-input-380-1496d1b45479>:2: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   pd.set_option('display.max_colwidth', -1)
#               Movie Title  Year  Score  Adjusted Score            Director  \
# 0    My Salinger Year      2020  71     75253.0         Philippe Falardeau
# 1    Palmer                2021  72     77750.0         Fisher Stevens
# 2    Cruella               2021  74     96584.0         Craig Gillespie
# 3    Percy Vs Goliath      2020  75     77000.0         Clark Johnson
# 4    Pixie                 2020  75     77250.0         Barnaby Thompson
# ..     ...                  ...  ..         ...                      ...
# 183  Mayor                 2020  100    101625.0        David Osit
# 184  Slalom                2020  100    102197.0        CharlÃ¨ne Favier
# 185  Identifying Features  2020  98     100788.0        Fernanda Valadez
# ...

# %% [markdown]
# ## Exporting the data to CSV (comma-separated values) and excel files

# %%
# Write data to excel file
movies_info.to_excel("datasinking_info.xlsx", index = False, header = True)
